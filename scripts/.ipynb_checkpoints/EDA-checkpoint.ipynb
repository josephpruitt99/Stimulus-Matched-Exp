# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path

# %%
data_path = Path.cwd().parent/'data'/'cleaned_exp1'

# %%
for i in data_path.iterdir():
    print(i)
# Out:
# /Users/josephpruitt/Desktop/SDT_Exp/data/cleaned_exp1/all_pid_exp1A_clean.csv
# /Users/josephpruitt/Desktop/SDT_Exp/data/cleaned_exp1/.DS_Store
# /Users/josephpruitt/Desktop/SDT_Exp/data/cleaned_exp1/exp1A_3_cleaned.csv

# %%
df = pd.read_csv(data_path/'all_pid_exp1A_clean.csv')

# %%
#df = pd.read_csv(data_path/'exp1A_2_cleaned.csv')

# %%
fail_trials = df.loc[df.check_eye==0]
success_trials = df.loc[df.check_eye==1]

# %%
fail_trials.shape,success_trials.shape
# Out:
# ((22, 15), (32, 15))

# %%
success_trials
# Out:
#     trialsN Stimulus    position  signalOpac  CorrAns  trials.thisTrialN  \
# 0         1   signal   [2274, 0]         1.0      1.0                0.0
# 1         2   signal   [-557, 0]         1.0      1.0                1.0
# 2         3    noise   [2274, 0]         0.0      2.0                2.0
# 3         4   signal  [-1716, 0]         1.0      1.0                3.0
# 4         5    noise   [1716, 0]         0.0      2.0                4.0
# 6         7    noise  [-1716, 0]         0.0      2.0                6.0
# 7         8    noise   [1158, 0]         0.0      2.0                7.0
# 8         9    noise  [-2274, 0]         0.0      2.0                8.0
# 9        10   signal  [-1158, 0]         1.0      1.0                9.0
# 10       11   signal  [-2274, 0]         1.0      1.0               10.0
# 11       12    noise      [0, 0]         0.0      2.0               11.0
# 12       13   signal    [557, 0]         1.0      1.0               12.0
# ...

# %%
a = df.pivot_table(index= 'participant',columns = 'check_eye',values = 'trials.thisTrialN',aggfunc='count')
a = a/540
a
# Out:
# check_eye         0.0       1.0
# participant
# 3.0          0.040741  0.059259

# %%
acc_pos_sig = success_trials.pivot_table(index='participant',columns=['position','Stimulus'],values='answerResp.corr')

# %%
acc_pos = success_trials.pivot_table(index='participant',columns='position',values='answerResp.corr')

# %%
acc_pos
# Out:
# position     [-1158, 0]  [-1716, 0]  [-2274, 0]  [-557, 0]    [0, 0]  \
# participant
# 3.0                 0.0         0.4    0.666667        1.0  0.666667
#
# position     [1158, 0]  [1716, 0]  [2274, 0]  [557, 0]
# participant
# 3.0               0.25       0.75        0.4  0.333333

# %%
acc_pos = acc_pos [['[-2274, 0]','[-1716, 0]','[-1158, 0]', '[-557, 0]','[0, 0]', '[557, 0]','[1158, 0]','[1716, 0]',
                 '[2274, 0]']]

acc_pos
# Out:
# position     [-2274, 0]  [-1716, 0]  [-1158, 0]  [-557, 0]    [0, 0]  \
# participant
# 3.0            0.666667         0.4         0.0        1.0  0.666667
#
# position     [557, 0]  [1158, 0]  [1716, 0]  [2274, 0]
# participant
# 3.0          0.333333       0.25       0.75        0.4

# %%
acc_pos.mean()
# Out:
# position
# [-2274, 0]    0.666667
# [-1716, 0]    0.400000
# [-1158, 0]    0.000000
# [-557, 0]     1.000000
# [0, 0]        0.666667
# [557, 0]      0.333333
# [1158, 0]     0.250000
# [1716, 0]     0.750000
# [2274, 0]     0.400000
# dtype: float64

# %%
acc_pos_sig = acc_pos_sig [['[-2274, 0]','[-1716, 0]','[-1158, 0]','[-557, 0]','[0, 0]', '[557, 0]','[1158, 0]','[1716, 0]',
                 '[2274, 0]']]
acc_pos_sig
# Out:
# position    [-2274, 0]        [-1716, 0]           [-1158, 0]         \
# Stimulus         noise signal      noise    signal      noise signal
# participant
# 3.0                0.0    1.0        0.5  0.333333        0.0    0.0
#
# position    [-557, 0]        [0, 0]        [557, 0]        [1158, 0]  \
# Stimulus        noise signal  noise signal    noise signal     noise
# participant
# 3.0               1.0    1.0    0.5    1.0      1.0    0.0       0.0
#
# position              [1716, 0]        [2274, 0]
# Stimulus       signal     noise signal     noise signal
# participant
# 3.0          0.333333       0.5    1.0  0.333333    0.5

# %%
success_trials['slider.response'] = success_trials['slider.response'].astype('float')
# Out:
# <ipython-input-28-74d66a053c52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   success_trials['slider.response'] = success_trials['slider.response'].astype('float')

# %%
conf_pos = success_trials.pivot_table(index='participant',columns=['position'],
                                      values='slider.response')

# %%
conf_pos
# Out:
# position     [-1158, 0]  [-1716, 0]  [-2274, 0]  [-557, 0]    [0, 0]  \
# participant
# 3.0                 2.5         2.8         3.0        2.0  3.333333
#
# position     [1158, 0]  [1716, 0]  [2274, 0]  [557, 0]
# participant
# 3.0                1.5       2.25        3.0  2.666667
